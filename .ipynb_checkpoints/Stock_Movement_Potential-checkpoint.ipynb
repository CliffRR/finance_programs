# %%
from collections import defaultdict
import yahoo_fin.stock_info as si
import yahoo_fin.options as ops
import numpy as np 
import pandas as pd
import math
from datetime import datetime

# %%
#---------------------------------------------Location for Functions--------------------------------------------------

# Python program to convert a list to string     
# Function to convert  
def listToString(List_Name): 
    
    # initialize an empty string
    string = "" 
    
    # traverse in the string  
    for i in List_Name: 
        string += i  
    
    # return string  
    return string

# %%
def StockPotentialUpwards(Current_stock_price, standard_deviations, volatility, time):
    Volatility_with_Time = (volatility * math.sqrt(time)) 
    
    Expected_Stock_Price = Current_stock_price * math.exp(standard_deviations * Volatility_with_Time)
    return Expected_Stock_Price


def StockPotentialDownwards(Current_stock_price, standard_deviations, volatility, time):
    Volatility_with_Time = (volatility * math.sqrt(time)) 
    
    Expected_Stock_Price = Current_stock_price * math.exp((-standard_deviations) * Volatility_with_Time)
    return Expected_Stock_Price

# %%
#Variables

ticker_symbol = 'mu'
live_price = si.get_live_price(ticker_symbol)
standard_deviations_allowed_for_movement = 1

expiration_date = '06/04/2021'
year = int(expiration_date[6:10])
month = int(expiration_date[0:2])
day = int(expiration_date[3:5])

# %%
stock_call_options = ops.get_calls(ticker_symbol,expiration_date)
stock_put_options = ops.get_puts(ticker_symbol, expiration_date)
stock_call_options
#stock_put_options
# Out:
#         Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0   MU210604C00050000   2021-05-14 3:10PM EDT    50.0       30.10  30.20
# 1   MU210604C00055000   2021-05-04 2:05PM EDT    55.0       28.95  25.05
# 2   MU210604C00060000  2021-05-10 11:16AM EDT    60.0       21.50  19.70
# 3   MU210604C00065000  2021-05-14 12:36PM EDT    65.0       14.60  15.10
# 4   MU210604C00070000   2021-05-12 9:53AM EDT    70.0        9.90  10.70
# 5   MU210604C00073500  2021-05-17 12:06AM EDT    73.5        7.13   7.60
# 6   MU210604C00075000   2021-05-14 3:52PM EDT    75.0        6.05   6.35
# 7   MU210604C00076500   2021-05-17 9:59AM EDT    76.5        3.60   5.25
# 8   MU210604C00077000   2021-05-17 9:57AM EDT    77.0        3.50   4.90
# 9   MU210604C00077500  2021-05-17 12:06AM EDT    77.5        4.30   4.55
# 10  MU210604C00078000   2021-05-17 1:38PM EDT    78.0        3.55   4.20
# 11  MU210604C00079000   2021-05-17 3:57PM EDT    79.0        3.60   3.60
# 12  MU210604C00080000   2021-05-17 3:57PM EDT    80.0        3.10   3.00
# 13  MU210604C00081000  2021-05-17 11:04AM EDT    81.0        2.09   2.62
# 14  MU210604C00082000   2021-05-17 1:49PM EDT    82.0        2.04   2.14
# 15  MU210604C00082500   2021-05-17 3:53PM EDT    82.5        1.95   1.94
# 16  MU210604C00083000   2021-05-17 2:28PM EDT    83.0        1.67   1.76
# 17  MU210604C00083500   2021-05-14 2:15PM EDT    83.5        1.43   1.59
# 18  MU210604C00084000  2021-05-14 12:26PM EDT    84.0        1.36   1.43
# 19  MU210604C00084500   2021-05-17 1:40PM EDT    84.5        1.05   1.26
# 20  MU210604C00085000   2021-05-17 3:55PM EDT    85.0        1.25   1.17
# 21  MU210604C00085500  2021-05-17 12:31PM EDT    85.5        0.92   1.05
# 22  MU210604C00086000   2021-05-17 3:55PM EDT    86.0        1.01   0.95
# 23  MU210604C00086500  2021-05-13 10:34AM EDT    86.5        0.78   0.86
# 24  MU210604C00087000   2021-05-14 3:15PM EDT    87.0        0.70   0.77
# 25  MU210604C00087500   2021-05-17 3:46PM EDT    87.5        0.70   0.69
# 26  MU210604C00088000   2021-05-17 1:39PM EDT    88.0        0.50   0.57
# 27  MU210604C00088500   2021-05-17 3:47PM EDT    88.5        0.58   0.21
# 28  MU210604C00089000  2021-05-12 12:09PM EDT    89.0        0.33   0.50
# 29  MU210604C00089500  2021-05-11 11:56AM EDT    89.5        0.37   0.45
# 30  MU210604C00090000   2021-05-17 3:11PM EDT    90.0        0.41   0.40
# 31  MU210604C00090500   2021-05-12 3:36PM EDT    90.5        0.23   0.33
# 32  MU210604C00091000   2021-05-14 3:50PM EDT    91.0        0.34   0.33
# 33  MU210604C00091500  2021-05-04 10:54AM EDT    91.5        0.34   0.26
# 34  MU210604C00092000   2021-05-14 2:21PM EDT    92.0        0.23   0.25
# 35  MU210604C00092500  2021-05-17 10:50AM EDT    92.5        0.26   0.23
# 36  MU210604C00093000   2021-05-17 1:26PM EDT    93.0        0.20   0.18
# 37  MU210604C00093500   2021-05-13 3:06PM EDT    93.5        0.19   0.17
# 38  MU210604C00094000   2021-05-17 3:46PM EDT    94.0        0.21   0.18
# 39  MU210604C00094500  2021-05-14 12:11PM EDT    94.5        0.13   0.13
# 40  MU210604C00095000  2021-05-17 12:47PM EDT    95.0        0.16   0.16
# 41  MU210604C00095500   2021-05-13 3:42PM EDT    95.5        0.16   0.08
# 42  MU210604C00096000   2021-05-07 2:24PM EDT    96.0        0.10   0.09
# 43  MU210604C00100000   2021-05-14 2:21PM EDT   100.0        0.08   0.07
# 44  MU210604C00105000  2021-04-28 12:27PM EDT   105.0        0.09   0.05
# 45  MU210604C00115000  2021-04-29 10:38AM EDT   115.0        0.15   0.01
#
#       Ask  Change % Change Volume  Open Interest Implied Volatility
# 0   33.00    0.00        -      1             27            171.29%
# 1   27.70    0.00        -      -              1            135.64%
# 2   22.70    0.00        -     10             23            105.08%
# 3   17.80    0.00        -      1              1             89.94%
# 4   12.75    0.00        -      4              4             73.19%
# 5    9.80    0.00        -      -              5             65.04%
# 6    7.65    0.00        -      1            182             53.76%
# 7    7.00   -1.40  -28.00%     16              1             55.76%
# 8    7.15   -0.15   -4.11%     22              8             58.98%
# 9    5.45    0.00        -      -             17             54.83%
# 10   5.00    0.75  +26.79%     14              1             52.52%
# 11   3.80    0.20   +5.88%     21             87             43.29%
# 12   3.25    0.30  +10.71%     97            150             42.97%
# 13   2.70   -0.41  -16.40%    141            180             41.90%
# 14   4.00    0.00        -     52            276             53.15%
# 15   2.08    0.07   +3.72%    144            241             41.85%
# 16   1.89    0.02   +1.21%     30            139             41.70%
# 17   1.79    0.00        -     41             52             42.73%
# 18   1.56   -0.04   -2.86%     13            140             41.60%
# 19   1.44   -0.05   -4.55%      4             78             42.02%
# 20   1.28    0.13  +11.61%     65            325             41.60%
# 21   1.16    0.02   +2.22%      7             85             41.65%
# 22   1.03    0.08   +8.60%     31            173             41.38%
# 23   0.96    0.02   +2.63%      1             31             42.04%
# 24   0.88   -0.08  -10.26%      1            136             42.36%
# 25   0.80    0.28  +66.67%     21             79             42.55%
# 26   0.75   -0.08  -13.79%      7             39             43.24%
# 27   1.40    0.02   +3.57%      3             92             57.42%
# 28   0.64   -0.26  -44.07%      1             80             44.09%
# 29   0.56    0.00        -      1             96             43.75%
# 30   0.47    0.01   +2.50%     17            649             42.97%
# 31   0.51    0.00        -      2            121             45.46%
# 32   0.40   -0.02   -5.56%      1             48             43.80%
# 33   0.42    0.00        -      5             12             45.80%
# 34   0.40   -0.05  -17.86%      7             87             46.53%
# 35   0.36   -0.48  -64.86%      5             10             46.58%
# 36   0.35    0.00        -      1             72             47.56%
# 37   0.33    0.00        -      2             33             48.15%
# 38   0.33   -0.16  -43.24%      5             10             49.41%
# 39   0.29    0.00        -      4              3             49.12%
# 40   0.27    0.00        -      1            315             49.51%
# 41   0.26    0.00        -     10             21             50.29%
# 42   0.23   -0.05  -33.33%      8            230             50.10%
# 43   0.27   -0.01  -11.11%      1            264             55.57%
# 44   0.12   -0.21  -70.00%      3              3             58.20%
# 45   0.25    0.00        -      -             11             79.20%

# %%
#Figure out which strike im working with and then use the row associated with it
#Future references: Volume = 8

Row_of_Strike_Put = 1
strike_price_put = stock_put_options.iloc[Row_of_Strike_Put][2]
Implied_Volatility_Put = stock_put_options.iloc[Row_of_Strike_Put][10]

Row_of_Strike_Call = 13
strike_price_call = stock_call_options.iloc[Row_of_Strike_Call][2]
Implied_Volatility_Call = stock_call_options.iloc[Row_of_Strike_Call][10]
#Implied_Volatility_Call

# %%
#Im getting rid of the percent (%) and turning it into a decimal 

Actual_Implied_Volatility_Call = Implied_Volatility_Call.replace('%','')
Actual_Implied_Volatility_Call = float(Actual_Implied_Volatility_Call)
Actual_Implied_Volatility_Call = Actual_Implied_Volatility_Call/100
#Actual_Implied_Volatility_Call

Actual_Implied_Volatility_Put = Implied_Volatility_Put.replace('%','')
Actual_Implied_Volatility_Put = float(Actual_Implied_Volatility_Put)
Actual_Implied_Volatility_Put = Actual_Implied_Volatility_Put/100
#Actual_Implied_Volatility_Put

# %%
Days_Remaining_Expiration_List = []
expiration = datetime(year, month, day)
difference = expiration - datetime.now() 
left_over_days = str(difference)
# Ex: 8954 days, 7:03:45.765329

# %%
#To remove the space in left_over_days

for i in left_over_days:
    if i == ' ':
        break
    Days_Remaining_Expiration_List.append(i)
    
Days_Remaining_Expiration =int(listToString(Days_Remaining_Expiration_List))

Days_Remaining_Fraction = Days_Remaining_Expiration/365

# %%
Answer = str(input("Upward or Downward stock movement? "))
if Answer == 'Upward':
    print('The stock would move up to approximately ' + str(StockPotentialUpwards(live_price, standard_deviations_allowed_for_movement, Actual_Implied_Volatility_Call, Days_Remaining_Fraction)) + ' if it moved ' + str(standard_deviations_allowed_for_movement) + ' standard deviations in exactly ' + str(Days_Remaining_Expiration) + ' days.')
    
elif Answer == 'Downward':
    print('The stock would move down to approximately ' + str(StockPotentialDownwards(live_price, standard_deviations_allowed_for_movement, Actual_Implied_Volatility_Put, Days_Remaining_Fraction)) + ' if it moved ' + str(standard_deviations_allowed_for_movement) + ' standard deviations in exactly ' + str(Days_Remaining_Expiration) + ' days.')
# Out:
# Upward or Downward stock movement? Upward
# The stock would move up to approximately 87.9981259798316 if it moved 1 standard deviations in exactly 17 days.
