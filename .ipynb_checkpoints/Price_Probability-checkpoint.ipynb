# %%
from collections import defaultdict
import yahoo_fin.stock_info as si
import yahoo_fin.options as ops
import numpy as np 
import pandas as pd
import math
from datetime import datetime

# %%
#---------------------------------------------Location for Functions--------------------------------------------------

# Python program to convert a list to string     
# Function to convert  
def listToString(List_Name): 
    
    # initialize an empty string
    string = "" 
    
    # traverse in the string  
    for i in List_Name: 
        string += i  
    
    # return string  
    return string

# %%
#---------------------------------------------BlackScholes Functions-------------------------------------------------- 
#Formula for d1

def NormalDistribution(p,s,v,t):
    A = math.log(p/s) #1st part of the numerator  
    C = (v * math.sqrt(t)) #the denominator

    d1 = ((A) / C)


#Formula for y1
    E = float(.2316419 * abs(d1))
    y1 = float((1 / (1 + E))) 


#Formula for z1
    G = (-1 * ((d1 ** 2)/2))
    z1 = float(.3989423 * (math.exp(G)))  



    I = 1.330274 * (y1 ** 5)
    J = 1.821256 * (y1 ** 4)
    K = 1.781478 * (y1 ** 3)
    L = .356538 * (y1 ** 2)
    M = .3193815 * y1 
    x1 = 1 - (z1 * (I - J + K - L + M))

    d3 = 1 - x1



#Cumulative Normal Distribution is returned
    if d1 < 0:
        return d3 
 
    elif d1 > 0:
        return x1

# %%
ticker_symbol = 'MU'
ticker_symbol_live_price = si.get_live_price(ticker_symbol)

expiration_date = '06/04/2021'
year = int(expiration_date[6:10])
month = int(expiration_date[0:2])
day = int(expiration_date[3:5])

Stock_Price_Goal = 87
Price_in_Question = 84

Max_percent_distance_from_stock_price = abs((Stock_Price_Goal - ticker_symbol_live_price)) / ticker_symbol_live_price

Max_distance_from_stock_price = (1 + Max_percent_distance_from_stock_price) * ticker_symbol_live_price 
Min_Subtraction = Max_percent_distance_from_stock_price * ticker_symbol_live_price
Min_distance_from_stock_price = ticker_symbol_live_price - Min_Subtraction
Max_distance_from_stock_price
# Out:
# 87.0

# %%
Min_distance_from_stock_price
# Out:
# 71.90280151367188

# %%
#so i can see what row my strike price is at

stock_options = ops.get_calls(ticker_symbol, expiration_date)
#stock_options = ops.get_puts(ticker_symbol, expiration_date)
stock_options
# Out:
#         Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0   MU210604C00050000   2021-05-14 3:10PM EDT    50.0       30.10  29.65
# 1   MU210604C00055000   2021-05-04 2:05PM EDT    55.0       28.95  24.70
# 2   MU210604C00060000  2021-05-10 11:16AM EDT    60.0       21.50  19.85
# 3   MU210604C00065000  2021-05-14 12:36PM EDT    65.0       14.60  15.00
# 4   MU210604C00070000   2021-05-12 9:53AM EDT    70.0        9.90  10.25
# 5   MU210604C00073500  2021-05-17 12:06AM EDT    73.5        7.13   7.05
# 6   MU210604C00075000   2021-05-14 3:52PM EDT    75.0        6.05   5.90
# 7   MU210604C00076500   2021-05-17 9:59AM EDT    76.5        3.60   4.80
# 8   MU210604C00077000   2021-05-17 9:57AM EDT    77.0        3.50   4.50
# 9   MU210604C00077500  2021-05-17 12:06AM EDT    77.5        4.30   4.15
# 10  MU210604C00078000  2021-05-17 10:48AM EDT    78.0        4.00   3.85
# 11  MU210604C00079000   2021-05-14 3:50PM EDT    79.0        3.10   3.25
# 12  MU210604C00080000   2021-05-17 9:59AM EDT    80.0        2.08   2.75
# 13  MU210604C00081000  2021-05-17 10:56AM EDT    81.0        2.38   2.29
# 14  MU210604C00082000  2021-05-17 10:43AM EDT    82.0        2.03   1.89
# 15  MU210604C00082500  2021-05-17 10:37AM EDT    82.5        1.66   1.73
# 16  MU210604C00083000  2021-05-12 12:44PM EDT    83.0        1.30   1.56
# 17  MU210604C00083500   2021-05-14 2:15PM EDT    83.5        1.43   1.42
# 18  MU210604C00084000  2021-05-14 12:26PM EDT    84.0        1.05   1.26
# 19  MU210604C00084500   2021-05-11 3:15PM EDT    84.5        1.10   1.14
# 20  MU210604C00085000   2021-05-14 1:58PM EDT    85.0        0.85   1.03
# 21  MU210604C00085500   2021-05-14 1:52PM EDT    85.5        0.90   0.93
# 22  MU210604C00086000  2021-05-17 10:32AM EDT    86.0        0.68   0.83
# 23  MU210604C00086500  2021-05-13 10:34AM EDT    86.5        0.76   0.75
# 24  MU210604C00087000   2021-05-14 3:15PM EDT    87.0        0.78   0.66
# 25  MU210604C00087500  2021-05-17 10:48AM EDT    87.5        0.66   0.59
# 26  MU210604C00088000   2021-05-17 9:43AM EDT    88.0        0.50   0.56
# 27  MU210604C00088500   2021-05-14 2:36PM EDT    88.5        0.56   0.50
# 28  MU210604C00089000  2021-05-12 12:09PM EDT    89.0        0.59   0.45
# 29  MU210604C00089500  2021-05-11 11:56AM EDT    89.5        0.37   0.40
# 30  MU210604C00090000  2021-05-17 10:54AM EDT    90.0        0.37   0.37
# 31  MU210604C00090500   2021-05-12 3:36PM EDT    90.5        0.23   0.33
# 32  MU210604C00091000   2021-05-14 3:50PM EDT    91.0        0.36   0.30
# 33  MU210604C00091500  2021-05-04 10:54AM EDT    91.5        0.34   0.27
# 34  MU210604C00092000   2021-05-14 2:21PM EDT    92.0        0.23   0.25
# 35  MU210604C00092500  2021-05-17 10:50AM EDT    92.5        0.26   0.23
# 36  MU210604C00093000   2021-05-13 3:47PM EDT    93.0        0.20   0.21
# 37  MU210604C00093500   2021-05-13 3:06PM EDT    93.5        0.19   0.20
# 38  MU210604C00094000  2021-05-10 10:53AM EDT    94.0        0.37   0.18
# 39  MU210604C00094500  2021-05-14 12:11PM EDT    94.5        0.13   0.16
# 40  MU210604C00095000   2021-05-14 1:07PM EDT    95.0        0.16   0.15
# 41  MU210604C00095500   2021-05-13 3:42PM EDT    95.5        0.16   0.00
# 42  MU210604C00096000   2021-05-07 2:24PM EDT    96.0        0.10   0.10
# 43  MU210604C00100000   2021-05-14 2:21PM EDT   100.0        0.08   0.07
# 44  MU210604C00105000  2021-04-28 12:27PM EDT   105.0        0.30   0.05
# 45  MU210604C00115000  2021-04-29 10:38AM EDT   115.0        0.15   0.02
#
#       Ask  Change % Change Volume  Open Interest Implied Volatility
# 0   30.20    0.00        -      1             27            130.08%
# 1   25.10    0.00        -      -              1            106.25%
# 2   20.15    0.00        -     10             23             89.65%
# 3   15.20    0.00        -      1              1             72.56%
# 4   10.40    0.00        -      4              4             57.62%
# 5    7.35    0.00        -      -              5             52.10%
# 6    6.30    0.00        -     39            182             51.98%
# 7    5.05   -1.40  -28.00%     16              1             47.51%
# 8    4.75   -0.15   -4.11%     22              8             47.56%
# 9    4.35    0.00        -      -             17             45.97%
# 10   4.00    1.20  +42.86%     13              1             45.00%
# 11   3.45   -0.30   -8.82%      4             87             44.65%
# 12   2.89   -0.72  -25.71%     31            150             43.51%
# 13   2.41   -0.12   -4.80%    100            180             42.80%
# 14   2.01   -0.01   -0.49%      6            276             42.48%
# 15   1.86   -0.22  -11.70%      2            241             42.80%
# 16   1.66   -0.35  -21.21%      2            139             42.19%
# 17   1.53    0.00        -     41             52             42.48%
# 18   1.37   -0.35  -25.00%     11            140             42.14%
# 19   1.24    0.00        -      2             78             42.09%
# 20   1.12   -0.27  -24.11%     14            325             42.07%
# 21   1.01    0.00        -     17             85             42.04%
# 22   0.94   -0.25  -26.88%      4            173             42.60%
# 23   0.82    0.00        -      1             31             42.07%
# 24   0.74    0.00        -     15            136             42.14%
# 25   0.68    0.24  +57.14%     20             79             42.53%
# 26   0.64   -0.08  -13.79%      4             39             43.21%
# 27   0.57    0.00        -      6             92             43.12%
# 28   0.52    0.00        -      2             80             43.36%
# 29   0.48    0.00        -      1             96             43.80%
# 30   0.42   -0.03   -7.50%     11            649             43.56%
# 31   0.38    0.00        -      2            121             43.70%
# 32   0.37    0.00        -      2             48             44.73%
# 33   0.34    0.00        -      5             12             45.02%
# 34   0.31   -0.05  -17.86%      7             87             45.31%
# 35   0.28   -0.48  -64.86%      5             10             45.41%
# 36   0.27    0.00        -     30             72             46.24%
# 37   0.25    0.00        -      2             33             46.58%
# 38   0.21    0.00        -      1             10             46.00%
# 39   0.23    0.00        -      4              3             48.05%
# 40   0.22    0.00        -      4            315             48.73%
# 41   0.00    0.00        -     10             21             25.00%
# 42   0.31   -0.05  -33.33%      8            230             50.20%
# 43   0.27   -0.01  -11.11%      1            264             56.45%
# 44   0.12    0.00        -      1              3             58.98%
# 45   0.21    0.00        -      -             11             77.93%

# %%
Option_Data = {}


i=0
while i < len(stock_options):
    if (stock_options['Strike'][i] <= Max_distance_from_stock_price) and (stock_options['Strike'][i] >= Min_distance_from_stock_price):
#This is to get Volume Data
        if stock_options['Volume'][i] == '-':
            stock_options['Volume'][i] = 0 
        Option_Data.setdefault('Volume',[]).append(float(stock_options['Volume'][i]))
#this is to get the Implied Volatility Data
        
        stock_options['Implied Volatility'][i] = stock_options['Implied Volatility'][i].replace('%','')
        Option_Data.setdefault('Implied_Volatilty',[]).append(float(stock_options['Implied Volatility'][i])/100)
        
#Distance from stock price (Distance Weighting Factor)
        if ((abs(stock_options['Strike'][i] - ticker_symbol_live_price)/ ticker_symbol_live_price) < Max_percent_distance_from_stock_price):
            Distance_Weighting_Factor = (((abs(stock_options['Strike'][i] - ticker_symbol_live_price)/ ticker_symbol_live_price) - Max_percent_distance_from_stock_price) ** 2) / (Max_percent_distance_from_stock_price ** 2)

        
        elif ((abs(stock_options['Strike'][i] - ticker_symbol_live_price)/ ticker_symbol_live_price) == Max_percent_distance_from_stock_price):
            Distance_Weighting_Factor = Max_percent_distance_from_stock_price
        Option_Data.setdefault('Distance_Weighting_Factor',[]).append(Distance_Weighting_Factor)

    i += 1 
Option_Data
# Out:
# /Users/creinoso/opt/anaconda3/envs/Algo_Course/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/creinoso/opt/anaconda3/envs/Algo_Course/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# {'Volume': [0.0,
#   39.0,
#   16.0,
#   22.0,
#   0.0,
#   13.0,
#   4.0,
#   31.0,
#   100.0,
#   6.0,
#   2.0,
#   2.0,
#   41.0,
#   11.0,
#   2.0,
#   14.0,
#   17.0,
#   4.0,
#   1.0,
#   15.0],
#  'Implied_Volatilty': [0.521,
#   0.5197999999999999,
#   0.47509999999999997,
#   0.4756,
#   0.4597,
#   0.45,
#   0.4465,
#   0.4351,
#   0.428,
#   0.42479999999999996,
#   0.428,
#   0.4219,
#   0.42479999999999996,
#   0.4214,
#   0.42090000000000005,
#   0.4207,
#   0.4204,
#   0.426,
#   0.4207,
#   0.4214],
#  'Distance_Weighting_Factor': [0.04476978837508058,
#   0.16834698324685662,
#   0.3708973852791586,
#   0.45596378754782063,
#   0.5498049906120965,
#   0.6524209944719865,
#   0.8839774045786084,
#   0.8599304779701717,
#   0.6317856572842079,
#   0.4387400397807001,
#   0.355379432222367,
#   0.2807936254596479,
#   0.21498261949254302,
#   0.15794641432105197,
#   0.10968500994517502,
#   0.07019840636491198,
#   0.03948660358026304,
#   0.01754960159122802,
#   0.004387400397807005,
#   0.09500901395391179]}

# %%
#Get the total volume

x = 0 
Total_Volume = 0
for x in range (len(Option_Data['Volume'])):
    Total_Volume += Option_Data['Volume'][x]
    x += 1

Total_Volume
# Out:
# 340.0

# %%
#Make a list with the Volume Weighting Factor

Volume_Weighting_Factor = []


for i in range (len(Option_Data['Volume'])):
    Current_Volume_Weighting_Factor = Option_Data['Volume'][i] / Total_Volume
    Volume_Weighting_Factor.append(Current_Volume_Weighting_Factor)
    
Volume_Weighting_Factor
# Out:
# [0.0,
#  0.11470588235294117,
#  0.047058823529411764,
#  0.06470588235294118,
#  0.0,
#  0.03823529411764706,
#  0.011764705882352941,
#  0.09117647058823529,
#  0.29411764705882354,
#  0.01764705882352941,
#  0.0058823529411764705,
#  0.0058823529411764705,
#  0.12058823529411765,
#  0.03235294117647059,
#  0.0058823529411764705,
#  0.041176470588235294,
#  0.05,
#  0.011764705882352941,
#  0.0029411764705882353,
#  0.04411764705882353]

# %%
#This gets the actual Implied Volatilty 
Total_Numerator = 0
Total_Denominator = 0

for values in range(len(Option_Data['Volume'])):
    Total_Numerator += Volume_Weighting_Factor[values] * Option_Data['Distance_Weighting_Factor'][values] * Option_Data['Implied_Volatilty'][values]
    Total_Denominator += Volume_Weighting_Factor[values] * Option_Data['Distance_Weighting_Factor'][values]
Implied_Volatility = Total_Numerator/Total_Denominator

# %%
Days_Remaining_Expiration_List = []


#to get the left over days 
expiration = datetime(year, month, day)
difference = expiration - datetime.now() 
left_over_days = str(difference)

# %%
#To remove the space in left_over_days

for i in left_over_days:
    if i == ' ':
        break
    Days_Remaining_Expiration_List.append(i)
    
Days_Remaining_Expiration = int(listToString(Days_Remaining_Expiration_List))


Days_Remaining_Fraction = float(Days_Remaining_Expiration/365)

# %%
Prob_Below_Certain_Number = 1 - NormalDistribution(ticker_symbol_live_price, Price_in_Question, Implied_Volatility, Days_Remaining_Fraction)
print('Probability of being below '+ str(Price_in_Question) +' = ' + str(Prob_Below_Certain_Number))
# Out:
# Probability of being below 84 = 0.721086322116061

# %%
Prob_Above_Certain_Number = NormalDistribution(ticker_symbol_live_price, Price_in_Question, Implied_Volatility, Days_Remaining_Fraction)
print('Probability of being above '+ str(Price_in_Question) +' = ' + str(Prob_Above_Certain_Number))
# Out:
# Probability of being above 84 = 0.27891367788393895
